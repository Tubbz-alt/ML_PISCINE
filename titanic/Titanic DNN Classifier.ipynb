# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

from plotnine import *
import warnings
import matplotlib.cbook
warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation)
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load the data preprocessed in EDA:

# %%
full_df = pd.read_csv("full_df.csv")
full_df = full_df.set_index("PassengerId")
full_df
# Out:
#               Age        Cabin Embarked      Fare  \
# PassengerId
# 1            22.0          NaN        S    7.2500
# 2            38.0          C85        C   71.2833
# 3            26.0          NaN        S    7.9250
# 4            35.0         C123        S   53.1000
# 5            35.0          NaN        S    8.0500
# 6             NaN          NaN        Q    8.4583
# 7            54.0          E46        S   51.8625
# 8             2.0          NaN        S   21.0750
# 9            27.0          NaN        S   11.1333
# 10           14.0          NaN        C   30.0708
# 11            4.0           G6        S   16.7000
# 12           58.0         C103        S   26.5500
# 13           20.0          NaN        S    8.0500
# 14           39.0          NaN        S   31.2750
# 15           14.0          NaN        S    7.8542
# 16           55.0          NaN        S   16.0000
# 17            2.0          NaN        Q   29.1250
# 18            NaN          NaN        S   13.0000
# 19           31.0          NaN        S   18.0000
# 20            NaN          NaN        C    7.2250
# 21           35.0          NaN        S   26.0000
# 22           34.0          D56        S   13.0000
# 23           15.0          NaN        Q    8.0292
# 24           28.0           A6        S   35.5000
# 25            8.0          NaN        S   21.0750
# 26           38.0          NaN        S   31.3875
# 27            NaN          NaN        C    7.2250
# 28           19.0  C23 C25 C27        S  263.0000
# 29            NaN          NaN        Q    7.8792
# 30            NaN          NaN        S    7.8958
# ...           ...          ...      ...       ...
# 1280         21.0          NaN        Q    7.7500
# 1281          6.0          NaN        S   21.0750
# 1282         23.0          B24        S   93.5000
# 1283         51.0          D28        S   39.4000
# 1284         13.0          NaN        S   20.2500
# 1285         47.0          NaN        S   10.5000
# 1286         29.0          NaN        S   22.0250
# 1287         18.0          C31        S   60.0000
# 1288         24.0          NaN        Q    7.2500
# 1289         48.0          B41        C   79.2000
# 1290         22.0          NaN        S    7.7750
# 1291         31.0          NaN        Q    7.7333
# 1292         30.0           C7        S  164.8667
# 1293         38.0          NaN        S   21.0000
# 1294         22.0          NaN        C   59.4000
# 1295         17.0          NaN        S   47.1000
# 1296         43.0          D40        C   27.7208
# 1297         20.0          D38        C   13.8625
# 1298         23.0          NaN        S   10.5000
# 1299         50.0          C80        C  211.5000
# 1300          NaN          NaN        Q    7.7208
# 1301          3.0          NaN        S   13.7750
# 1302          NaN          NaN        Q    7.7500
# 1303         37.0          C78        Q   90.0000
# 1304         28.0          NaN        S    7.7750
# 1305          NaN          NaN        S    8.0500
# 1306         39.0         C105        C  108.9000
# 1307         38.5          NaN        S    7.2500
# 1308          NaN          NaN        S    8.0500
# 1309          NaN          NaN        C   22.3583
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris      0       3
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      0       1
# 3                                       Heikkinen, Miss. Laina      0       3
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      0       1
# 5                                     Allen, Mr. William Henry      0       3
# 6                                             Moran, Mr. James      0       3
# 7                                      McCarthy, Mr. Timothy J      0       1
# 8                               Palsson, Master. Gosta Leonard      1       3
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      2       3
# 10                         Nasser, Mrs. Nicholas (Adele Achem)      0       2
# 11                             Sandstrom, Miss. Marguerite Rut      1       3
# 12                                    Bonnell, Miss. Elizabeth      0       1
# 13                              Saundercock, Mr. William Henry      0       3
# 14                                 Andersson, Mr. Anders Johan      5       3
# 15                        Vestrom, Miss. Hulda Amanda Adolfina      0       3
# 16                            Hewlett, Mrs. (Mary D Kingcome)       0       2
# 17                                        Rice, Master. Eugene      1       3
# 18                                Williams, Mr. Charles Eugene      0       2
# 19           Vander Planke, Mrs. Julius (Emelia Maria Vande...      0       3
# 20                                     Masselmani, Mrs. Fatima      0       3
# 21                                        Fynney, Mr. Joseph J      0       2
# 22                                       Beesley, Mr. Lawrence      0       2
# 23                                 McGowan, Miss. Anna "Annie"      0       3
# 24                                Sloper, Mr. William Thompson      0       1
# 25                               Palsson, Miss. Torborg Danira      1       3
# 26           Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...      5       3
# 27                                     Emir, Mr. Farred Chehab      0       3
# 28                              Fortune, Mr. Charles Alexander      2       1
# 29                               O'Dwyer, Miss. Ellen "Nellie"      0       3
# 30                                         Todoroff, Mr. Lalio      0       3
# ...                                                        ...    ...     ...
# 1280                                      Canavan, Mr. Patrick      0       3
# 1281                               Palsson, Master. Paul Folke      1       3
# 1282                                Payne, Mr. Vivian Ponsonby      0       1
# 1283            Lines, Mrs. Ernest H (Elizabeth Lindsey James)      1       1
# 1284                             Abbott, Master. Eugene Joseph      2       3
# 1285                                      Gilbert, Mr. William      0       2
# 1286                                  Kink-Heilmann, Mr. Anton      1       3
# 1287            Smith, Mrs. Lucien Philip (Mary Eloise Hughes)      0       1
# 1288                                      Colbert, Mr. Patrick      0       3
# 1289         Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...      1       1
# 1290                            Larsson-Rondberg, Mr. Edvard A      0       3
# 1291                                  Conlon, Mr. Thomas Henry      0       3
# 1292                                   Bonnell, Miss. Caroline      0       1
# 1293                                           Gale, Mr. Harry      0       2
# 1294                            Gibson, Miss. Dorothy Winifred      1       1
# 1295                                    Carrau, Mr. Jose Pedro      0       1
# 1296                              Frauenthal, Mr. Isaac Gerald      0       1
# 1297              Nourney, Mr. Alfred (Baron von Drachstedt")"      0       2
# 1298                                 Ware, Mr. William Jeffery      0       2
# 1299                                Widener, Mr. George Dunton      1       1
# 1300                           Riordan, Miss. Johanna Hannah""      0       3
# 1301                                 Peacock, Miss. Treasteall      1       3
# 1302                                    Naughton, Miss. Hannah      0       3
# 1303           Minahan, Mrs. William Edward (Lillian E Thorpe)      0       1
# 1304                            Henriksson, Miss. Jenny Lovisa      0       3
# 1305                                        Spector, Mr. Woolf      0       3
# 1306                              Oliva y Ocana, Dona. Fermina      0       1
# 1307                              Saether, Mr. Simon Sivertsen      0       3
# 1308                                       Ware, Mr. Frederick      0       3
# 1309                                  Peter, Master. Michael J      1       3
#
#                 Sex  SibSp  Survived              Ticket
# PassengerId
# 1              male      1       0.0           A/5 21171
# 2            female      1       1.0            PC 17599
# 3            female      0       1.0    STON/O2. 3101282
# 4            female      1       1.0              113803
# 5              male      0       0.0              373450
# 6              male      0       0.0              330877
# 7              male      0       0.0               17463
# 8              male      3       0.0              349909
# 9            female      0       1.0              347742
# 10           female      1       1.0              237736
# 11           female      1       1.0             PP 9549
# 12           female      0       1.0              113783
# 13             male      0       0.0           A/5. 2151
# 14             male      1       0.0              347082
# 15           female      0       0.0              350406
# 16           female      0       1.0              248706
# 17             male      4       0.0              382652
# 18             male      0       1.0              244373
# 19           female      1       0.0              345763
# 20           female      0       1.0                2649
# 21             male      0       0.0              239865
# 22             male      0       1.0              248698
# 23           female      0       1.0              330923
# 24             male      0       1.0              113788
# 25           female      3       0.0              349909
# 26           female      1       1.0              347077
# 27             male      0       0.0                2631
# 28             male      3       0.0               19950
# 29           female      0       1.0              330959
# 30             male      0       0.0              349216
# ...             ...    ...       ...                 ...
# 1280           male      0       NaN              364858
# 1281           male      3       NaN              349909
# 1282           male      0       NaN               12749
# 1283         female      0       NaN            PC 17592
# 1284           male      0       NaN           C.A. 2673
# 1285           male      0       NaN          C.A. 30769
# 1286           male      3       NaN              315153
# 1287         female      1       NaN               13695
# 1288           male      0       NaN              371109
# 1289         female      1       NaN               13567
# 1290           male      0       NaN              347065
# 1291           male      0       NaN               21332
# 1292         female      0       NaN               36928
# 1293           male      1       NaN               28664
# 1294         female      0       NaN              112378
# 1295           male      0       NaN              113059
# 1296           male      1       NaN               17765
# 1297           male      0       NaN       SC/PARIS 2166
# 1298           male      1       NaN               28666
# 1299           male      1       NaN              113503
# 1300         female      0       NaN              334915
# 1301         female      1       NaN  SOTON/O.Q. 3101315
# 1302         female      0       NaN              365237
# 1303         female      1       NaN               19928
# 1304         female      0       NaN              347086
# 1305           male      0       NaN           A.5. 3236
# 1306         female      0       NaN            PC 17758
# 1307           male      0       NaN  SOTON/O.Q. 3101262
# 1308           male      0       NaN              359309
# 1309           male      1       NaN                2668
#
# [1309 rows x 11 columns]

# %% [markdown]
# Some preprocessing:

# %%
#Take care of missing age by filling with 0 and making a binary column AgeAvail
full_df["AgeAvail"] = np.nan
full_df["AgeAvail"] = full_df["Age"].apply(lambda x: 0 if pd.isnull(x) else 1)#new binary column
full_df["Age"] = full_df["Age"].fillna(0) #fill missing ages with 0
full_df = full_df[pd.notnull(full_df["Embarked"])] #drop 2 rows with Embarked N/A
full_df = full_df[full_df["Age"] < 80] #drop 1 outlier male survived 80 yr old
full_df["RelAb"] = full_df["SibSp"] + full_df["Parch"]#create combined column
full_df
# Out:
#               Age        Cabin Embarked      Fare  \
# PassengerId
# 1            22.0          NaN        S    7.2500
# 2            38.0          C85        C   71.2833
# 3            26.0          NaN        S    7.9250
# 4            35.0         C123        S   53.1000
# 5            35.0          NaN        S    8.0500
# 6             0.0          NaN        Q    8.4583
# 7            54.0          E46        S   51.8625
# 8             2.0          NaN        S   21.0750
# 9            27.0          NaN        S   11.1333
# 10           14.0          NaN        C   30.0708
# 11            4.0           G6        S   16.7000
# 12           58.0         C103        S   26.5500
# 13           20.0          NaN        S    8.0500
# 14           39.0          NaN        S   31.2750
# 15           14.0          NaN        S    7.8542
# 16           55.0          NaN        S   16.0000
# 17            2.0          NaN        Q   29.1250
# 18            0.0          NaN        S   13.0000
# 19           31.0          NaN        S   18.0000
# 20            0.0          NaN        C    7.2250
# 21           35.0          NaN        S   26.0000
# 22           34.0          D56        S   13.0000
# 23           15.0          NaN        Q    8.0292
# 24           28.0           A6        S   35.5000
# 25            8.0          NaN        S   21.0750
# 26           38.0          NaN        S   31.3875
# 27            0.0          NaN        C    7.2250
# 28           19.0  C23 C25 C27        S  263.0000
# 29            0.0          NaN        Q    7.8792
# 30            0.0          NaN        S    7.8958
# ...           ...          ...      ...       ...
# 1280         21.0          NaN        Q    7.7500
# 1281          6.0          NaN        S   21.0750
# 1282         23.0          B24        S   93.5000
# 1283         51.0          D28        S   39.4000
# 1284         13.0          NaN        S   20.2500
# 1285         47.0          NaN        S   10.5000
# 1286         29.0          NaN        S   22.0250
# 1287         18.0          C31        S   60.0000
# 1288         24.0          NaN        Q    7.2500
# 1289         48.0          B41        C   79.2000
# 1290         22.0          NaN        S    7.7750
# 1291         31.0          NaN        Q    7.7333
# 1292         30.0           C7        S  164.8667
# 1293         38.0          NaN        S   21.0000
# 1294         22.0          NaN        C   59.4000
# 1295         17.0          NaN        S   47.1000
# 1296         43.0          D40        C   27.7208
# 1297         20.0          D38        C   13.8625
# 1298         23.0          NaN        S   10.5000
# 1299         50.0          C80        C  211.5000
# 1300          0.0          NaN        Q    7.7208
# 1301          3.0          NaN        S   13.7750
# 1302          0.0          NaN        Q    7.7500
# 1303         37.0          C78        Q   90.0000
# 1304         28.0          NaN        S    7.7750
# 1305          0.0          NaN        S    8.0500
# 1306         39.0         C105        C  108.9000
# 1307         38.5          NaN        S    7.2500
# 1308          0.0          NaN        S    8.0500
# 1309          0.0          NaN        C   22.3583
#
#                                                           Name  Parch  Pclass  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris      0       3
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      0       1
# 3                                       Heikkinen, Miss. Laina      0       3
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      0       1
# 5                                     Allen, Mr. William Henry      0       3
# 6                                             Moran, Mr. James      0       3
# 7                                      McCarthy, Mr. Timothy J      0       1
# 8                               Palsson, Master. Gosta Leonard      1       3
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      2       3
# 10                         Nasser, Mrs. Nicholas (Adele Achem)      0       2
# 11                             Sandstrom, Miss. Marguerite Rut      1       3
# 12                                    Bonnell, Miss. Elizabeth      0       1
# 13                              Saundercock, Mr. William Henry      0       3
# 14                                 Andersson, Mr. Anders Johan      5       3
# 15                        Vestrom, Miss. Hulda Amanda Adolfina      0       3
# 16                            Hewlett, Mrs. (Mary D Kingcome)       0       2
# 17                                        Rice, Master. Eugene      1       3
# 18                                Williams, Mr. Charles Eugene      0       2
# 19           Vander Planke, Mrs. Julius (Emelia Maria Vande...      0       3
# 20                                     Masselmani, Mrs. Fatima      0       3
# 21                                        Fynney, Mr. Joseph J      0       2
# 22                                       Beesley, Mr. Lawrence      0       2
# 23                                 McGowan, Miss. Anna "Annie"      0       3
# 24                                Sloper, Mr. William Thompson      0       1
# 25                               Palsson, Miss. Torborg Danira      1       3
# 26           Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...      5       3
# 27                                     Emir, Mr. Farred Chehab      0       3
# 28                              Fortune, Mr. Charles Alexander      2       1
# 29                               O'Dwyer, Miss. Ellen "Nellie"      0       3
# 30                                         Todoroff, Mr. Lalio      0       3
# ...                                                        ...    ...     ...
# 1280                                      Canavan, Mr. Patrick      0       3
# 1281                               Palsson, Master. Paul Folke      1       3
# 1282                                Payne, Mr. Vivian Ponsonby      0       1
# 1283            Lines, Mrs. Ernest H (Elizabeth Lindsey James)      1       1
# 1284                             Abbott, Master. Eugene Joseph      2       3
# 1285                                      Gilbert, Mr. William      0       2
# 1286                                  Kink-Heilmann, Mr. Anton      1       3
# 1287            Smith, Mrs. Lucien Philip (Mary Eloise Hughes)      0       1
# 1288                                      Colbert, Mr. Patrick      0       3
# 1289         Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...      1       1
# 1290                            Larsson-Rondberg, Mr. Edvard A      0       3
# 1291                                  Conlon, Mr. Thomas Henry      0       3
# 1292                                   Bonnell, Miss. Caroline      0       1
# 1293                                           Gale, Mr. Harry      0       2
# 1294                            Gibson, Miss. Dorothy Winifred      1       1
# 1295                                    Carrau, Mr. Jose Pedro      0       1
# 1296                              Frauenthal, Mr. Isaac Gerald      0       1
# 1297              Nourney, Mr. Alfred (Baron von Drachstedt")"      0       2
# 1298                                 Ware, Mr. William Jeffery      0       2
# 1299                                Widener, Mr. George Dunton      1       1
# 1300                           Riordan, Miss. Johanna Hannah""      0       3
# 1301                                 Peacock, Miss. Treasteall      1       3
# 1302                                    Naughton, Miss. Hannah      0       3
# 1303           Minahan, Mrs. William Edward (Lillian E Thorpe)      0       1
# 1304                            Henriksson, Miss. Jenny Lovisa      0       3
# 1305                                        Spector, Mr. Woolf      0       3
# 1306                              Oliva y Ocana, Dona. Fermina      0       1
# 1307                              Saether, Mr. Simon Sivertsen      0       3
# 1308                                       Ware, Mr. Frederick      0       3
# 1309                                  Peter, Master. Michael J      1       3
#
#                 Sex  SibSp  Survived              Ticket  AgeAvail  RelAb
# PassengerId
# 1              male      1       0.0           A/5 21171         1      1
# 2            female      1       1.0            PC 17599         1      1
# 3            female      0       1.0    STON/O2. 3101282         1      0
# 4            female      1       1.0              113803         1      1
# 5              male      0       0.0              373450         1      0
# 6              male      0       0.0              330877         0      0
# 7              male      0       0.0               17463         1      0
# 8              male      3       0.0              349909         1      4
# 9            female      0       1.0              347742         1      2
# 10           female      1       1.0              237736         1      1
# 11           female      1       1.0             PP 9549         1      2
# 12           female      0       1.0              113783         1      0
# 13             male      0       0.0           A/5. 2151         1      0
# 14             male      1       0.0              347082         1      6
# 15           female      0       0.0              350406         1      0
# 16           female      0       1.0              248706         1      0
# 17             male      4       0.0              382652         1      5
# 18             male      0       1.0              244373         0      0
# 19           female      1       0.0              345763         1      1
# 20           female      0       1.0                2649         0      0
# 21             male      0       0.0              239865         1      0
# 22             male      0       1.0              248698         1      0
# 23           female      0       1.0              330923         1      0
# 24             male      0       1.0              113788         1      0
# 25           female      3       0.0              349909         1      4
# 26           female      1       1.0              347077         1      6
# 27             male      0       0.0                2631         0      0
# 28             male      3       0.0               19950         1      5
# 29           female      0       1.0              330959         0      0
# 30             male      0       0.0              349216         0      0
# ...             ...    ...       ...                 ...       ...    ...
# 1280           male      0       NaN              364858         1      0
# 1281           male      3       NaN              349909         1      4
# 1282           male      0       NaN               12749         1      0
# 1283         female      0       NaN            PC 17592         1      1
# 1284           male      0       NaN           C.A. 2673         1      2
# 1285           male      0       NaN          C.A. 30769         1      0
# 1286           male      3       NaN              315153         1      4
# 1287         female      1       NaN               13695         1      1
# 1288           male      0       NaN              371109         1      0
# 1289         female      1       NaN               13567         1      2
# 1290           male      0       NaN              347065         1      0
# 1291           male      0       NaN               21332         1      0
# 1292         female      0       NaN               36928         1      0
# 1293           male      1       NaN               28664         1      1
# 1294         female      0       NaN              112378         1      1
# 1295           male      0       NaN              113059         1      0
# 1296           male      1       NaN               17765         1      1
# 1297           male      0       NaN       SC/PARIS 2166         1      0
# 1298           male      1       NaN               28666         1      1
# 1299           male      1       NaN              113503         1      2
# 1300         female      0       NaN              334915         0      0
# 1301         female      1       NaN  SOTON/O.Q. 3101315         1      2
# 1302         female      0       NaN              365237         0      0
# 1303         female      1       NaN               19928         1      1
# 1304         female      0       NaN              347086         1      0
# 1305           male      0       NaN           A.5. 3236         0      0
# 1306         female      0       NaN            PC 17758         1      0
# 1307           male      0       NaN  SOTON/O.Q. 3101262         1      0
# 1308           male      0       NaN              359309         0      0
# 1309           male      1       NaN                2668         0      2
#
# [1306 rows x 13 columns]

# %%
qual_cols = ["AgeAvail","Embarked","Sex","Pclass"]
quant_cols = ["Age","RelAb"]

full_df[qual_cols]=full_df[qual_cols].applymap(str)
full_df[quant_cols] = full_df[quant_cols].astype("float64")

# %% [markdown]
# Split the data back into training and testing:

# %%
TR_TEST_SP = 888
train_df = full_df[:TR_TEST_SP]
test_df  = full_df[TR_TEST_SP:]
test_df = test_df.drop("Survived", axis = 1)
train_df["Survived"] = train_df["Survived"].apply(lambda x: float(x))
train_df
# Out:
# /home/mtolstokory/anaconda3/envs/42/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#               Age        Cabin Embarked      Fare  \
# PassengerId
# 1            22.0          NaN        S    7.2500
# 2            38.0          C85        C   71.2833
# 3            26.0          NaN        S    7.9250
# 4            35.0         C123        S   53.1000
# 5            35.0          NaN        S    8.0500
# 6             0.0          NaN        Q    8.4583
# 7            54.0          E46        S   51.8625
# 8             2.0          NaN        S   21.0750
# 9            27.0          NaN        S   11.1333
# 10           14.0          NaN        C   30.0708
# 11            4.0           G6        S   16.7000
# 12           58.0         C103        S   26.5500
# 13           20.0          NaN        S    8.0500
# 14           39.0          NaN        S   31.2750
# 15           14.0          NaN        S    7.8542
# 16           55.0          NaN        S   16.0000
# 17            2.0          NaN        Q   29.1250
# 18            0.0          NaN        S   13.0000
# 19           31.0          NaN        S   18.0000
# 20            0.0          NaN        C    7.2250
# 21           35.0          NaN        S   26.0000
# 22           34.0          D56        S   13.0000
# 23           15.0          NaN        Q    8.0292
# 24           28.0           A6        S   35.5000
# 25            8.0          NaN        S   21.0750
# 26           38.0          NaN        S   31.3875
# 27            0.0          NaN        C    7.2250
# 28           19.0  C23 C25 C27        S  263.0000
# 29            0.0          NaN        Q    7.8792
# 30            0.0          NaN        S    7.8958
# ...           ...          ...      ...       ...
# 862          21.0          NaN        S   11.5000
# 863          48.0          D17        S   25.9292
# 864           0.0          NaN        S   69.5500
# 865          24.0          NaN        S   13.0000
# 866          42.0          NaN        S   13.0000
# 867          27.0          NaN        C   13.8583
# 868          31.0          A24        S   50.4958
# 869           0.0          NaN        S    9.5000
# 870           4.0          NaN        S   11.1333
# 871          26.0          NaN        S    7.8958
# 872          47.0          D35        S   52.5542
# 873          33.0  B51 B53 B55        S    5.0000
# 874          47.0          NaN        S    9.0000
# 875          28.0          NaN        C   24.0000
# 876          15.0          NaN        C    7.2250
# 877          20.0          NaN        S    9.8458
# 878          19.0          NaN        S    7.8958
# 879           0.0          NaN        S    7.8958
# 880          56.0          C50        C   83.1583
# 881          25.0          NaN        S   26.0000
# 882          33.0          NaN        S    7.8958
# 883          22.0          NaN        S   10.5167
# 884          28.0          NaN        S   10.5000
# 885          25.0          NaN        S    7.0500
# 886          39.0          NaN        Q   29.1250
# 887          27.0          NaN        S   13.0000
# 888          19.0          B42        S   30.0000
# 889           0.0          NaN        S   23.4500
# 890          26.0         C148        C   30.0000
# 891          32.0          NaN        Q    7.7500
#
#                                                           Name  Parch Pclass  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris      0      3
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      0      1
# 3                                       Heikkinen, Miss. Laina      0      3
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      0      1
# 5                                     Allen, Mr. William Henry      0      3
# 6                                             Moran, Mr. James      0      3
# 7                                      McCarthy, Mr. Timothy J      0      1
# 8                               Palsson, Master. Gosta Leonard      1      3
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      2      3
# 10                         Nasser, Mrs. Nicholas (Adele Achem)      0      2
# 11                             Sandstrom, Miss. Marguerite Rut      1      3
# 12                                    Bonnell, Miss. Elizabeth      0      1
# 13                              Saundercock, Mr. William Henry      0      3
# 14                                 Andersson, Mr. Anders Johan      5      3
# 15                        Vestrom, Miss. Hulda Amanda Adolfina      0      3
# 16                            Hewlett, Mrs. (Mary D Kingcome)       0      2
# 17                                        Rice, Master. Eugene      1      3
# 18                                Williams, Mr. Charles Eugene      0      2
# 19           Vander Planke, Mrs. Julius (Emelia Maria Vande...      0      3
# 20                                     Masselmani, Mrs. Fatima      0      3
# 21                                        Fynney, Mr. Joseph J      0      2
# 22                                       Beesley, Mr. Lawrence      0      2
# 23                                 McGowan, Miss. Anna "Annie"      0      3
# 24                                Sloper, Mr. William Thompson      0      1
# 25                               Palsson, Miss. Torborg Danira      1      3
# 26           Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...      5      3
# 27                                     Emir, Mr. Farred Chehab      0      3
# 28                              Fortune, Mr. Charles Alexander      2      1
# 29                               O'Dwyer, Miss. Ellen "Nellie"      0      3
# 30                                         Todoroff, Mr. Lalio      0      3
# ...                                                        ...    ...    ...
# 862                                Giles, Mr. Frederick Edward      0      2
# 863          Swift, Mrs. Frederick Joel (Margaret Welles Ba...      0      1
# 864                          Sage, Miss. Dorothy Edith "Dolly"      2      3
# 865                                     Gill, Mr. John William      0      2
# 866                                   Bystrom, Mrs. (Karolina)      0      2
# 867                               Duran y More, Miss. Asuncion      0      2
# 868                       Roebling, Mr. Washington Augustus II      0      1
# 869                                van Melkebeke, Mr. Philemon      0      3
# 870                            Johnson, Master. Harold Theodor      1      3
# 871                                          Balkic, Mr. Cerin      0      3
# 872           Beckwith, Mrs. Richard Leonard (Sallie Monypeny)      1      1
# 873                                   Carlsson, Mr. Frans Olof      0      1
# 874                                Vander Cruyssen, Mr. Victor      0      3
# 875                      Abelson, Mrs. Samuel (Hannah Wizosky)      0      2
# 876                           Najib, Miss. Adele Kiamie "Jane"      0      3
# 877                              Gustafsson, Mr. Alfred Ossian      0      3
# 878                                       Petroff, Mr. Nedelio      0      3
# 879                                         Laleff, Mr. Kristo      0      3
# 880              Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)      1      1
# 881               Shelley, Mrs. William (Imanita Parrish Hall)      1      2
# 882                                         Markun, Mr. Johann      0      3
# 883                               Dahlberg, Miss. Gerda Ulrika      0      3
# 884                              Banfield, Mr. Frederick James      0      2
# 885                                     Sutehall, Mr. Henry Jr      0      3
# 886                       Rice, Mrs. William (Margaret Norton)      5      3
# 887                                      Montvila, Rev. Juozas      0      2
# 888                               Graham, Miss. Margaret Edith      0      1
# 889                   Johnston, Miss. Catherine Helen "Carrie"      2      3
# 890                                      Behr, Mr. Karl Howell      0      1
# 891                                        Dooley, Mr. Patrick      0      3
#
#                 Sex  SibSp  Survived            Ticket AgeAvail  RelAb
# PassengerId
# 1              male      1       0.0         A/5 21171        1    1.0
# 2            female      1       1.0          PC 17599        1    1.0
# 3            female      0       1.0  STON/O2. 3101282        1    0.0
# 4            female      1       1.0            113803        1    1.0
# 5              male      0       0.0            373450        1    0.0
# 6              male      0       0.0            330877        0    0.0
# 7              male      0       0.0             17463        1    0.0
# 8              male      3       0.0            349909        1    4.0
# 9            female      0       1.0            347742        1    2.0
# 10           female      1       1.0            237736        1    1.0
# 11           female      1       1.0           PP 9549        1    2.0
# 12           female      0       1.0            113783        1    0.0
# 13             male      0       0.0         A/5. 2151        1    0.0
# 14             male      1       0.0            347082        1    6.0
# 15           female      0       0.0            350406        1    0.0
# 16           female      0       1.0            248706        1    0.0
# 17             male      4       0.0            382652        1    5.0
# 18             male      0       1.0            244373        0    0.0
# 19           female      1       0.0            345763        1    1.0
# 20           female      0       1.0              2649        0    0.0
# 21             male      0       0.0            239865        1    0.0
# 22             male      0       1.0            248698        1    0.0
# 23           female      0       1.0            330923        1    0.0
# 24             male      0       1.0            113788        1    0.0
# 25           female      3       0.0            349909        1    4.0
# 26           female      1       1.0            347077        1    6.0
# 27             male      0       0.0              2631        0    0.0
# 28             male      3       0.0             19950        1    5.0
# 29           female      0       1.0            330959        0    0.0
# 30             male      0       0.0            349216        0    0.0
# ...             ...    ...       ...               ...      ...    ...
# 862            male      1       0.0             28134        1    1.0
# 863          female      0       1.0             17466        1    0.0
# 864          female      8       0.0          CA. 2343        0   10.0
# 865            male      0       0.0            233866        1    0.0
# 866          female      0       1.0            236852        1    0.0
# 867          female      1       1.0     SC/PARIS 2149        1    1.0
# 868            male      0       0.0          PC 17590        1    0.0
# 869            male      0       0.0            345777        0    0.0
# 870            male      1       1.0            347742        1    2.0
# 871            male      0       0.0            349248        1    0.0
# 872          female      1       1.0             11751        1    2.0
# 873            male      0       0.0               695        1    0.0
# 874            male      0       0.0            345765        1    0.0
# 875          female      1       1.0         P/PP 3381        1    1.0
# 876          female      0       1.0              2667        1    0.0
# 877            male      0       0.0              7534        1    0.0
# 878            male      0       0.0            349212        1    0.0
# 879            male      0       0.0            349217        0    0.0
# 880          female      0       1.0             11767        1    1.0
# 881          female      0       1.0            230433        1    1.0
# 882            male      0       0.0            349257        1    0.0
# 883          female      0       0.0              7552        1    0.0
# 884            male      0       0.0  C.A./SOTON 34068        1    0.0
# 885            male      0       0.0   SOTON/OQ 392076        1    0.0
# 886          female      0       0.0            382652        1    5.0
# 887            male      0       0.0            211536        1    0.0
# 888          female      0       1.0            112053        1    0.0
# 889          female      1       0.0        W./C. 6607        0    3.0
# 890            male      0       1.0            111369        1    0.0
# 891            male      0       0.0            370376        1    0.0
#
# [888 rows x 13 columns]

# %%
TRAIN_PTS = 888
SPLIT = int((TRAIN_PTS/100.)*70)

# %%
train_df = train_df.reindex(np.random.permutation(train_df.index))
valid_df = train_df[SPLIT:]
train_df = train_df[:SPLIT]

# %%
y_train = train_df["Survived"]
del train_df["Survived"]

y_valid = valid_df["Survived"]
del valid_df["Survived"]

del full_df["Survived"]
y_valid.head(5)
train_df = train_df[qual_cols+quant_cols]
valid_df = valid_df[qual_cols+quant_cols]
test_df = test_df[qual_cols+quant_cols]
full_df = full_df[qual_cols+quant_cols]

# %% [markdown]
# Create TF columns:

# %%
def make_columns(df):
    keep_num = ["Age", "RelAb"] # 
    keep_cat = ["AgeAvail","Pclass","Sex","Embarked"] #
    
    numeric_features = df[keep_num]
    #.select_dtypes(include = ["float64"])
    
    
    numeric_columns = [tf.feature_column.numeric_column(key = feature) for feature in numeric_features]
    categoric_features = df[keep_cat]
    #.select_dtypes(exclude=["float64"]) 
    
    categoric_dict = {}
    for feature in categoric_features:
        categoric_dict[feature] = df[feature].unique()
    
    categoric_columns = [tf.feature_column.indicator_column((tf.feature_column.categorical_column_with_vocabulary_list(
        key=feature, vocabulary_list=list(categoric_dict[feature])))) for feature in categoric_features]
    return numeric_columns, categoric_columns

# %%
numeric_columns, categoric_columns = make_columns(full_df)

# %%
OUT_DIR = "tf_files_titanic"

# %%
# !rm -rf tf_files_titanic/

# %%
#def my_f1(labels,predictions):
    
   # return {"f1" : tf.contrib.metrics.f1_score()}

# %% [markdown]
# Define model function:

# %%
def train_my_estimator(learning_rate, steps, batch_size):
    
    my_optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
    my_optimizer = tf.contrib.estimator.clip_gradients_by_norm(my_optimizer, 5.0)
    
    my_estimator = tf.estimator.DNNClassifier(
        feature_columns = numeric_columns + categoric_columns,
        optimizer = my_optimizer,
        hidden_units = [32,16,16],
        dropout = 0.1,
        config=tf.estimator.RunConfig(keep_checkpoint_max=1).replace(save_summary_steps=2),
        model_dir=OUT_DIR)
    
    #my_estimator = tf.contrib.estimator.add_metrics(my_estimator, rmse)
    
    periods = 10
    steps_per_period = int(steps/periods)
    
    train_input_fn = tf.estimator.inputs.pandas_input_fn(x=train_df,y=y_train,batch_size=batch_size,shuffle=True)
    predict_train_input_fn = tf.estimator.inputs.pandas_input_fn(x=train_df,y=y_train,batch_size=batch_size,shuffle=False)
    predict_valid_input_fn = tf.estimator.inputs.pandas_input_fn(x=valid_df,y=y_valid,batch_size=batch_size,shuffle=False)
    
    training_errors = []
    validation_errors = []
    training_accuracies = [] 
    validation_accuracies = []
    training_f1s = []
    validation_f1s = []
    
    for period in range(0, periods):
        my_estimator.train(input_fn=train_input_fn,steps=steps_per_period)
        
        train_eval = my_estimator.evaluate(input_fn=predict_train_input_fn)
        valid_eval = my_estimator.evaluate(input_fn=predict_valid_input_fn)
        
        train_acc = train_eval["accuracy"]
        train_loss  =  train_eval["loss"]
        train_f1 = (2.0 * train_eval["precision"]*train_eval["recall"]) / (train_eval["precision"]+train_eval["recall"])
        valid_acc = valid_eval["accuracy"]
        valid_loss  = valid_eval["loss"]
        valid_f1 = (2.0 * valid_eval["precision"]*valid_eval["recall"]) / (valid_eval["precision"]+valid_eval["recall"])
        
        #print("Train error: {}".format(train_error))
        #print("Valid error: {}".format(valid_error))
        training_accuracies.append(train_acc)
        validation_accuracies.append(valid_acc)
        training_errors.append(train_loss)
        validation_errors.append(valid_loss)
        training_f1s.append(train_f1)
        validation_f1s.append(valid_f1)
        
        """
        # Take a break and compute probabilities.
        training_predictions = list(classifier.predict(input_fn=predict_training_input_fn))
        training_probabilities = np.array([item['probabilities'] for item in training_predictions])
        training_pred_class_id = np.array([item['class_ids'][0] for item in training_predictions])
        training_pred_one_hot = tf.keras.utils.to_categorical(training_pred_class_id,10)

        validation_predictions = list(classifier.predict(input_fn=predict_validation_input_fn))
        validation_probabilities = np.array([item['probabilities'] for item in validation_predictions])    
        validation_pred_class_id = np.array([item['class_ids'][0] for item in validation_predictions])
        validation_pred_one_hot = tf.keras.utils.to_categorical(validation_pred_class_id,10)    

        # Compute training and validation errors.
        training_log_loss = metrics.log_loss(training_targets, training_pred_one_hot)
        validation_log_loss = metrics.log_loss(validation_targets, validation_pred_one_hot)
        # Occasionally print the current loss.
        print("  period %02d : %0.2f" % (period, validation_log_loss))
        # Add the loss metrics from this period to our list.
        training_errors.append(training_log_loss)
        validation_errors.append(validation_log_loss)

        train_accuracy = metrics.accuracy_score(training_targets, training_pred_class_id)
        valid_accuracy = metrics.accuracy_score(validation_targets, validation_pred_class_id)
        training_accuracies.append(train_accuracy)
        validation_accuracies.append(valid_accuracy)
        """
    
 
    # Calculate final predictions (not probabilities, as above).
    #final_predictions = my_estimator.predict(input_fn=predict_valid_input_fn)
    #final_predictions = np.array([item['class_ids'][0] for item in final_predictions])


    #accuracy = metrics.accuracy_score(y_valid, final_predictions)
    #print("Final accuracy (on validation data): %0.2f" % accuracy)

    f = plt.Figure()
    graph1 = f.add_subplot(311)
    graph2 = f.add_subplot(312,sharex=graph1)
    graph3 = f.add_subplot(313,sharex=graph1)
    
    ax = plt.subplot("311")
    ax.clear()
    ax.set_title("Accuracy over time")
    ax.plot(training_accuracies, label="training error")
    ax.plot(validation_accuracies, label="validation error")

    ax = plt.subplot("312")
    ax.clear()
    ax.set_title("Loss over time")
    ax.plot(training_errors, label="training loss")
    ax.plot(validation_errors, label="validation loss")
    
    ax = plt.subplot("313")
    ax.clear()
    ax.set_title("F1 over time")
    ax.plot(training_f1s, label="training f1")
    ax.plot(validation_f1s, label="validation f1")
    
    return my_estimator

# %% [markdown]
# Train the model:

# %%
model = train_my_estimator(learning_rate=0.01, steps = 400, batch_size=64)
# Out:
# INFO:tensorflow:Using config: {'_model_dir': 'tf_files_titanic', '_tf_random_seed': None, '_save_summary_steps': 2, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 1, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f47c2c00390>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:From /home/mtolstokory/anaconda3/envs/42/lib/python3.6/site-packages/tensorflow/python/estimator/inputs/queues/feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /home/mtolstokory/anaconda3/envs/42/lib/python3.6/site-packages/tensorflow/python/estimator/inputs/queues/feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /home/mtolstokory/anaconda3/envs/42/lib/python3.6/site-packages/tensorflow/python/ops/sparse_ops.py:1165: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From /home/mtolstokory/anaconda3/envs/42/lib/python3.6/site-packages/tensorflow/python/training/monitored_session.py:804: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Saving checkpoints for 0 into tf_files_titanic/model.ckpt.
# INFO:tensorflow:loss = 65.10327, step = 0
# INFO:tensorflow:Saving checkpoints for 10 into tf_files_titanic/model.ckpt.
# INFO:tensorflow:Loss for final step: 28.177315.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-06:01:07
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_titanic/model.ckpt-10
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-06:01:08
# INFO:tensorflow:Saving dict for global step 10: accuracy = 0.6183575, accuracy_baseline = 0.6215781, auc = 0.6784533, auc_precision_recall = 0.5858595, average_loss = 0.6325998, global_step = 10, label/mean = 0.3784219, loss = 39.284447, precision = 0.0, prediction/mean = 0.360063, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10: tf_files_titanic/model.ckpt-10
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-06:01:09
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_titanic/model.ckpt-10
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-06:01:10
# INFO:tensorflow:Saving dict for global step 10: accuracy = 0.60674155, accuracy_baseline = 0.61048687, auc = 0.6351758, auc_precision_recall = 0.54972327, average_loss = 0.64495635, global_step = 10, label/mean = 0.3895131, loss = 34.440666, precision = 0.0, prediction/mean = 0.36304444, recall = 0.0
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10: tf_files_titanic/model.ckpt-10
# INFO:tensorflow:Calling model_fn.
# /home/mtolstokory/anaconda3/envs/42/lib/python3.6/site-packages/ipykernel_launcher.py:38: RuntimeWarning: invalid value encountered in double_scalars
# /home/mtolstokory/anaconda3/envs/42/lib/python3.6/site-packages/ipykernel_launcher.py:41: RuntimeWarning: invalid value encountered in double_scalars
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_titanic/model.ckpt-10
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 10 into tf_files_titanic/model.ckpt.
# INFO:tensorflow:loss = 42.342617, step = 10
# INFO:tensorflow:Saving checkpoints for 20 into tf_files_titanic/model.ckpt.
# INFO:tensorflow:Loss for final step: 28.80361.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-06:01:13
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_titanic/model.ckpt-20
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-06:01:14
# INFO:tensorflow:Saving dict for global step 20: accuracy = 0.7568438, accuracy_baseline = 0.6215781, auc = 0.82395554, auc_precision_recall = 0.7804674, average_loss = 0.5834367, global_step = 20, label/mean = 0.3784219, loss = 36.231422, precision = 0.92, prediction/mean = 0.41047814, recall = 0.39148936
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 20: tf_files_titanic/model.ckpt-20
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-06:01:15
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_titanic/model.ckpt-20
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-06:01:16
# INFO:tensorflow:Saving dict for global step 20: accuracy = 0.72659177, accuracy_baseline = 0.61048687, auc = 0.806837, auc_precision_recall = 0.77038366, average_loss = 0.5998029, global_step = 20, label/mean = 0.3895131, loss = 32.029472, precision = 0.8974359, prediction/mean = 0.40902933, recall = 0.33653846
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 20: tf_files_titanic/model.ckpt-20
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_titanic/model.ckpt-20
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 20 into tf_files_titanic/model.ckpt.
# INFO:tensorflow:loss = 38.72117, step = 20
# INFO:tensorflow:Saving checkpoints for 30 into tf_files_titanic/model.ckpt.
# INFO:tensorflow:Loss for final step: 23.934736.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-06:01:20
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_titanic/model.ckpt-30
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-06:01:20
# INFO:tensorflow:Saving dict for global step 30: accuracy = 0.74718195, accuracy_baseline = 0.6215781, auc = 0.8201245, auc_precision_recall = 0.7352616, average_loss = 0.5316135, global_step = 30, label/mean = 0.3784219, loss = 33.013203, precision = 0.8, prediction/mean = 0.37035808, recall = 0.4425532
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 30: tf_files_titanic/model.ckpt-30
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-06:01:21
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_titanic/model.ckpt-30
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-06:01:22
# INFO:tensorflow:Saving dict for global step 30: accuracy = 0.7340824, accuracy_baseline = 0.61048687, auc = 0.7726227, auc_precision_recall = 0.69516444, average_loss = 0.5645984, global_step = 30, label/mean = 0.3895131, loss = 30.149555, precision = 0.75384617, prediction/mean = 0.37951687, recall = 0.47115386
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 30: tf_files_titanic/model.ckpt-30
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_titanic/model.ckpt-30
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 30 into tf_files_titanic/model.ckpt.
# INFO:tensorflow:loss = 44.13031, step = 30
# INFO:tensorflow:Saving checkpoints for 40 into tf_files_titanic/model.ckpt.
# INFO:tensorflow:Loss for final step: 26.21738.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-06:01:26
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_titanic/model.ckpt-40
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-06:01:26
# INFO:tensorflow:Saving dict for global step 40: accuracy = 0.77133656, accuracy_baseline = 0.6215781, auc = 0.8471226, auc_precision_recall = 0.81609225, average_loss = 0.49826294, global_step = 40, label/mean = 0.3784219, loss = 30.94213, precision = 0.66431093, prediction/mean = 0.46147954, recall = 0.8
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 40: tf_files_titanic/model.ckpt-40
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-06:01:27
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_titanic/model.ckpt-40
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-06:01:28
# INFO:tensorflow:Saving dict for global step 40: accuracy = 0.7602996, accuracy_baseline = 0.61048687, auc = 0.82353115, auc_precision_recall = 0.8029473, average_loss = 0.5378023, global_step = 40, label/mean = 0.3895131, loss = 28.718643, precision = 0.65384614, prediction/mean = 0.462015, recall = 0.8173077
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 40: tf_files_titanic/model.ckpt-40
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_titanic/model.ckpt-40
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 40 into tf_files_titanic/model.ckpt.
# INFO:tensorflow:loss = 35.807842, step = 40
# INFO:tensorflow:Saving checkpoints for 50 into tf_files_titanic/model.ckpt.
# INFO:tensorflow:Loss for final step: 19.093393.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-06:01:32
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_titanic/model.ckpt-50
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-06:01:32
# INFO:tensorflow:Saving dict for global step 50: accuracy = 0.82930756, accuracy_baseline = 0.6215781, auc = 0.86836076, auc_precision_recall = 0.8417012, average_loss = 0.43544573, global_step = 50, label/mean = 0.3784219, loss = 27.04118, precision = 0.8241206, prediction/mean = 0.391322, recall = 0.69787234
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 50: tf_files_titanic/model.ckpt-50
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-06:01:33
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_titanic/model.ckpt-50
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-06:01:34
# INFO:tensorflow:Saving dict for global step 50: accuracy = 0.79026216, accuracy_baseline = 0.61048687, auc = 0.8332645, auc_precision_recall = 0.8035445, average_loss = 0.49024203, global_step = 50, label/mean = 0.3895131, loss = 26.178925, precision = 0.77272725, prediction/mean = 0.3892117, recall = 0.65384614
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 50: tf_files_titanic/model.ckpt-50
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_titanic/model.ckpt-50
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 50 into tf_files_titanic/model.ckpt.
# INFO:tensorflow:loss = 24.412373, step = 50
# INFO:tensorflow:Saving checkpoints for 60 into tf_files_titanic/model.ckpt.
# INFO:tensorflow:Loss for final step: 19.161077.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-06:01:38
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_titanic/model.ckpt-60
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-06:01:38
# INFO:tensorflow:Saving dict for global step 60: accuracy = 0.8228663, accuracy_baseline = 0.6215781, auc = 0.8668835, auc_precision_recall = 0.8503974, average_loss = 0.42349425, global_step = 60, label/mean = 0.3784219, loss = 26.298992, precision = 0.8834356, prediction/mean = 0.33810657, recall = 0.61276597
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 60: tf_files_titanic/model.ckpt-60
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-06:01:39
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_titanic/model.ckpt-60
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-06:01:40
# INFO:tensorflow:Saving dict for global step 60: accuracy = 0.7977528, accuracy_baseline = 0.61048687, auc = 0.81258845, auc_precision_recall = 0.7815826, average_loss = 0.49852806, global_step = 60, label/mean = 0.3895131, loss = 26.621399, precision = 0.8472222, prediction/mean = 0.3336069, recall = 0.58653843
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 60: tf_files_titanic/model.ckpt-60
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_titanic/model.ckpt-60
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 60 into tf_files_titanic/model.ckpt.
# INFO:tensorflow:loss = 25.495182, step = 60
# INFO:tensorflow:Saving checkpoints for 70 into tf_files_titanic/model.ckpt.
# INFO:tensorflow:Loss for final step: 18.96856.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-06:01:44
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_titanic/model.ckpt-70
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-06:01:44
# INFO:tensorflow:Saving dict for global step 70: accuracy = 0.8083736, accuracy_baseline = 0.6215781, auc = 0.86471176, auc_precision_recall = 0.84802026, average_loss = 0.45213684, global_step = 70, label/mean = 0.3784219, loss = 28.077698, precision = 0.9264706, prediction/mean = 0.285113, recall = 0.5361702
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 70: tf_files_titanic/model.ckpt-70
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-06:01:45
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_titanic/model.ckpt-70
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-06:01:46
# INFO:tensorflow:Saving dict for global step 70: accuracy = 0.78651685, accuracy_baseline = 0.61048687, auc = 0.8065419, auc_precision_recall = 0.7821505, average_loss = 0.539772, global_step = 70, label/mean = 0.3895131, loss = 28.823822, precision = 0.89830506, prediction/mean = 0.27611092, recall = 0.50961536
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 70: tf_files_titanic/model.ckpt-70
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_titanic/model.ckpt-70
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 70 into tf_files_titanic/model.ckpt.
# INFO:tensorflow:loss = 23.312872, step = 70
# INFO:tensorflow:Saving checkpoints for 80 into tf_files_titanic/model.ckpt.
# INFO:tensorflow:Loss for final step: 19.33659.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-06:01:50
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_titanic/model.ckpt-80
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-06:01:50
# INFO:tensorflow:Saving dict for global step 80: accuracy = 0.84219, accuracy_baseline = 0.6215781, auc = 0.88480324, auc_precision_recall = 0.8650419, average_loss = 0.38533714, global_step = 80, label/mean = 0.3784219, loss = 23.929438, precision = 0.8341463, prediction/mean = 0.40090865, recall = 0.7276596
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 80: tf_files_titanic/model.ckpt-80
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-06:01:51
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_titanic/model.ckpt-80
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-06:01:52
# INFO:tensorflow:Saving dict for global step 80: accuracy = 0.8164794, accuracy_baseline = 0.61048687, auc = 0.8377478, auc_precision_recall = 0.8092097, average_loss = 0.46482813, global_step = 80, label/mean = 0.3895131, loss = 24.821821, precision = 0.8021978, prediction/mean = 0.39474568, recall = 0.7019231
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 80: tf_files_titanic/model.ckpt-80
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_titanic/model.ckpt-80
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 80 into tf_files_titanic/model.ckpt.
# INFO:tensorflow:loss = 28.503227, step = 80
# INFO:tensorflow:Saving checkpoints for 90 into tf_files_titanic/model.ckpt.
# INFO:tensorflow:Loss for final step: 17.386307.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-06:01:56
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_titanic/model.ckpt-90
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-06:01:56
# INFO:tensorflow:Saving dict for global step 90: accuracy = 0.84219, accuracy_baseline = 0.6215781, auc = 0.88109356, auc_precision_recall = 0.86258334, average_loss = 0.3915032, global_step = 90, label/mean = 0.3784219, loss = 24.31235, precision = 0.87431693, prediction/mean = 0.38719675, recall = 0.68085104
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 90: tf_files_titanic/model.ckpt-90
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-06:01:58
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_titanic/model.ckpt-90
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-06:01:58
# INFO:tensorflow:Saving dict for global step 90: accuracy = 0.7977528, accuracy_baseline = 0.61048687, auc = 0.8269525, auc_precision_recall = 0.7822031, average_loss = 0.48583665, global_step = 90, label/mean = 0.3895131, loss = 25.943676, precision = 0.82051283, prediction/mean = 0.378344, recall = 0.61538464
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 90: tf_files_titanic/model.ckpt-90
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_titanic/model.ckpt-90
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 90 into tf_files_titanic/model.ckpt.
# INFO:tensorflow:loss = 33.637253, step = 90
# INFO:tensorflow:Saving checkpoints for 100 into tf_files_titanic/model.ckpt.
# INFO:tensorflow:Loss for final step: 22.260544.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-06:02:01
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_titanic/model.ckpt-100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-06:02:02
# INFO:tensorflow:Saving dict for global step 100: accuracy = 0.8389694, accuracy_baseline = 0.6215781, auc = 0.8839709, auc_precision_recall = 0.8648887, average_loss = 0.38366833, global_step = 100, label/mean = 0.3784219, loss = 23.825802, precision = 0.86885244, prediction/mean = 0.3775667, recall = 0.67659575
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 100: tf_files_titanic/model.ckpt-100
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-06:02:03
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_titanic/model.ckpt-100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-06:02:04
# INFO:tensorflow:Saving dict for global step 100: accuracy = 0.80898875, accuracy_baseline = 0.61048687, auc = 0.8443546, auc_precision_recall = 0.7901596, average_loss = 0.47092605, global_step = 100, label/mean = 0.3895131, loss = 25.14745, precision = 0.835443, prediction/mean = 0.36681992, recall = 0.63461536
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 100: tf_files_titanic/model.ckpt-100

# %% [markdown]
# Generate submission:

# %%
predict_test_input_fn = tf.estimator.inputs.pandas_input_fn(x=test_df,batch_size=64,shuffle=False)

generator = model.predict(input_fn=predict_test_input_fn)
predictions = [next(generator) for i in range(len(test_df))]
classes = [int(predictions[i]["classes"][0]) for i in range(len(predictions))]
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_titanic/model.ckpt-100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
submission = pd.DataFrame()
submission["PassengerId"] = test_df.index
submission = submission.set_index("PassengerId")
submission["Survived"] = classes
submission.to_csv("mtolstok_titanic_pred_DNN_est.csv")
