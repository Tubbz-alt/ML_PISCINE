# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

from plotnine import *
import warnings
import matplotlib.cbook
warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation)
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load the data that was preprocessed in EDA phase:

# %%
TRAIN_PTS = 1458
SPLIT = int((TRAIN_PTS/100.)*70)

# %%
qual_cols = ['MSSubClass', 'MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC','Fence', 'MiscFeature', 'SaleType', 'SaleCondition','MoSold', 'YrSold']
quant_cols = ['TotalArea','SalePrice','LotFrontage', 'MasVnrArea', 'LotArea', 'YearBuilt', 'YearRemodAdd', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea','BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal']

# %%
full_df = pd.read_csv("full_df.csv")
full_df = full_df.set_index("Id")
full_df
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch Alley  BedroomAbvGr BldgType BsmtCond  \
# Id
# 1        856.0     854.0        0.0  None           3.0     1Fam       TA
# 2       1262.0       0.0        0.0  None           3.0     1Fam       TA
# 3        920.0     866.0        0.0  None           3.0     1Fam       TA
# 4        961.0     756.0        0.0  None           3.0     1Fam       Gd
# 5       1145.0    1053.0        0.0  None           4.0     1Fam       TA
# 6        796.0     566.0      320.0  None           1.0     1Fam       TA
# 7       1694.0       0.0        0.0  None           3.0     1Fam       TA
# 8       1107.0     983.0        0.0  None           3.0     1Fam       TA
# 9       1022.0     752.0        0.0  None           2.0     1Fam       TA
# 10      1077.0       0.0        0.0  None           2.0   2fmCon       TA
# 11      1040.0       0.0        0.0  None           3.0     1Fam       TA
# 12      1182.0    1142.0        0.0  None           4.0     1Fam       TA
# 13       912.0       0.0        0.0  None           2.0     1Fam       TA
# 14      1494.0       0.0        0.0  None           3.0     1Fam       TA
# 15      1253.0       0.0        0.0  None           2.0     1Fam       TA
# 16       854.0       0.0        0.0  None           2.0     1Fam       TA
# 17      1004.0       0.0        0.0  None           2.0     1Fam       TA
# 18      1296.0       0.0        0.0  None           2.0   Duplex     None
# 19      1114.0       0.0        0.0  None           3.0     1Fam       TA
# 20      1339.0       0.0        0.0  None           3.0     1Fam       TA
# 21      1158.0    1218.0        0.0  None           4.0     1Fam       TA
# 22      1108.0       0.0        0.0  Grvl           3.0     1Fam       TA
# 23      1795.0       0.0        0.0  None           3.0     1Fam       TA
# 24      1060.0       0.0        0.0  None           3.0   TwnhsE       TA
# 25      1060.0       0.0        0.0  None           3.0     1Fam       TA
# 26      1600.0       0.0        0.0  None           3.0     1Fam       TA
# 27       900.0       0.0        0.0  None           3.0     1Fam       TA
# 28      1704.0       0.0        0.0  None           3.0     1Fam       TA
# 29      1600.0       0.0        0.0  None           2.0     1Fam       TA
# 30       520.0       0.0        0.0  None           1.0     1Fam       TA
# ...        ...       ...        ...   ...           ...      ...      ...
# 2890     641.0       0.0        0.0  None           2.0     1Fam       TA
# 2891     967.0     671.0        0.0  None           4.0     1Fam       TA
# 2892     729.0       0.0        0.0  None           2.0     1Fam     None
# 2893    1060.0     336.0        0.0  None           4.0   2fmCon       TA
# 2894     576.0     360.0        0.0  None           2.0     1Fam       Fa
# 2895    1778.0       0.0        0.0  None           2.0   TwnhsE       TA
# 2896    1646.0       0.0        0.0  None           2.0   TwnhsE       TA
# 2897    1625.0       0.0        0.0  None           3.0     1Fam       TA
# 2898    1664.0       0.0        0.0  None           4.0   Duplex       TA
# 2899    1491.0       0.0        0.0  None           3.0     1Fam       TA
# 2900    1210.0       0.0        0.0  None           3.0     1Fam       TA
# 2901    1650.0       0.0        0.0  None           2.0     1Fam       TA
# 2902    1403.0       0.0        0.0  None           2.0     1Fam       TA
# 2903    1960.0       0.0        0.0  None           3.0     1Fam       Gd
# 2904    1838.0       0.0        0.0  None           3.0     1Fam       TA
# 2905    1600.0       0.0        0.0  None           3.0     1Fam     None
# 2906    1368.0       0.0        0.0  None           2.0   Duplex       TA
# 2907     616.0     688.0        0.0  None           3.0   TwnhsE       TA
# 2908     874.0       0.0        0.0  None           3.0     1Fam       TA
# 2909    1652.0       0.0        0.0  None           4.0   Duplex       TA
# 2910     630.0       0.0        0.0  None           1.0    Twnhs       TA
# 2911     546.0     546.0        0.0  None           3.0   TwnhsE       TA
# 2912    1360.0       0.0        0.0  None           3.0     1Fam       TA
# 2913     546.0     546.0        0.0  None           3.0    Twnhs       TA
# 2914     546.0     546.0        0.0  None           3.0    Twnhs       TA
# 2915     546.0     546.0        0.0  None           3.0    Twnhs       TA
# 2916     546.0     546.0        0.0  None           3.0   TwnhsE       TA
# 2917    1224.0       0.0        0.0  None           4.0     1Fam       TA
# 2918     970.0       0.0        0.0  None           3.0     1Fam       TA
# 2919     996.0    1004.0        0.0  None           3.0     1Fam       TA
#
#      BsmtExposure  BsmtFinSF1  BsmtFinSF2   ...   SaleType ScreenPorch  \
# Id                                          ...
# 1              No       706.0         0.0   ...         WD         0.0
# 2              Gd       978.0         0.0   ...         WD         0.0
# 3              Mn       486.0         0.0   ...         WD         0.0
# 4              No       216.0         0.0   ...         WD         0.0
# 5              Av       655.0         0.0   ...         WD         0.0
# 6              No       732.0         0.0   ...         WD         0.0
# 7              Av      1369.0         0.0   ...         WD         0.0
# 8              Mn       859.0        32.0   ...         WD         0.0
# 9              No         0.0         0.0   ...         WD         0.0
# 10             No       851.0         0.0   ...         WD         0.0
# 11             No       906.0         0.0   ...         WD         0.0
# 12             No       998.0         0.0   ...        New         0.0
# 13             No       737.0         0.0   ...         WD       176.0
# 14             Av         0.0         0.0   ...        New         0.0
# 15             No       733.0         0.0   ...         WD         0.0
# 16             No         0.0         0.0   ...         WD         0.0
# 17             No       578.0         0.0   ...         WD         0.0
# 18           None         0.0         0.0   ...         WD         0.0
# 19             No       646.0         0.0   ...         WD         0.0
# 20             No       504.0         0.0   ...        COD         0.0
# 21             Av         0.0         0.0   ...        New         0.0
# 22             No         0.0         0.0   ...         WD         0.0
# 23             No         0.0         0.0   ...         WD         0.0
# 24             No       840.0         0.0   ...         WD         0.0
# 25             Mn       188.0       668.0   ...         WD         0.0
# 26             No         0.0         0.0   ...         WD         0.0
# 27             Mn       234.0       486.0   ...         WD         0.0
# 28             No      1218.0         0.0   ...         WD         0.0
# 29             Gd      1277.0         0.0   ...         WD         0.0
# 30             No         0.0         0.0   ...         WD         0.0
# ...           ...         ...         ...   ...        ...         ...
# 2890           No         0.0         0.0   ...         WD         0.0
# 2891           No         0.0         0.0   ...         WD         0.0
# 2892         None         0.0         0.0   ...         WD         0.0
# 2893           Mn         0.0         0.0   ...         WD         0.0
# 2894           No         0.0         0.0   ...         WD         0.0
# 2895           Gd      1573.0         0.0   ...        New       153.0
# 2896           Gd      1564.0         0.0   ...         WD       155.0
# 2897           Gd       776.0         0.0   ...         WD         0.0
# 2898           Mn         0.0         0.0   ...         WD         0.0
# 2899           No         0.0         0.0   ...         WD         0.0
# 2900           Av       576.0         0.0   ...         WD         0.0
# 2901           Gd       909.0         0.0   ...         WD       138.0
# 2902           Av      1136.0       116.0   ...         WD         0.0
# 2903           Av      1350.0         0.0   ...        New         0.0
# 2904           Gd      1455.0         0.0   ...        New         0.0
# 2905         None         0.0         0.0   ...         WD         0.0
# 2906           Gd      1243.0         0.0   ...         WD         0.0
# 2907           Mn         0.0         0.0   ...         WD         0.0
# 2908           No       441.0         0.0   ...         WD         0.0
# 2909           No       149.0         0.0   ...         WD         0.0
# 2910           Av       522.0         0.0   ...         WD         0.0
# 2911           No       252.0         0.0   ...         WD         0.0
# 2912           Av       119.0       344.0   ...         WD         0.0
# 2913           No       408.0         0.0   ...         WD         0.0
# 2914           No         0.0         0.0   ...         WD         0.0
# 2915           No         0.0         0.0   ...         WD         0.0
# 2916           No       252.0         0.0   ...         WD         0.0
# 2917           No      1224.0         0.0   ...         WD         0.0
# 2918           Av       337.0         0.0   ...         WD         0.0
# 2919           Av       758.0         0.0   ...         WD         0.0
#
#       Street  TotRmsAbvGrd TotalArea  TotalBsmtSF WoodDeckSF YearBuilt  \
# Id
# 1       Pave           8.0    2566.0        856.0        0.0    2003.0
# 2       Pave           6.0    2524.0       1262.0      298.0    1976.0
# 3       Pave           6.0    2706.0        920.0        0.0    2001.0
# 4       Pave           7.0    2473.0        756.0        0.0    1915.0
# 5       Pave           9.0    3343.0       1145.0      192.0    2000.0
# 6       Pave           5.0    2158.0        796.0       40.0    1993.0
# 7       Pave           7.0    3380.0       1686.0      255.0    2004.0
# 8       Pave           7.0    3197.0       1107.0      235.0    1973.0
# 9       Pave           8.0    2726.0        952.0       90.0    1931.0
# 10      Pave           5.0    2068.0        991.0        0.0    1939.0
# 11      Pave           5.0    2080.0       1040.0        0.0    1965.0
# 12      Pave          11.0    3499.0       1175.0      147.0    2005.0
# 13      Pave           4.0    1824.0        912.0      140.0    1962.0
# 14      Pave           7.0    2988.0       1494.0      160.0    2006.0
# 15      Pave           5.0    2506.0       1253.0        0.0    1960.0
# 16      Pave           5.0    1686.0        832.0       48.0    1929.0
# 17      Pave           5.0    2008.0       1004.0        0.0    1970.0
# 18      Pave           6.0    1296.0          0.0        0.0    1967.0
# 19      Pave           6.0    2228.0       1114.0        0.0    2004.0
# 20      Pave           6.0    2368.0       1029.0        0.0    1958.0
# 21      Pave           9.0    3534.0       1158.0      240.0    2005.0
# 22      Pave           6.0    1745.0        637.0        0.0    1930.0
# 23      Pave           7.0    3572.0       1777.0      171.0    2002.0
# 24      Pave           6.0    2100.0       1040.0      100.0    1976.0
# 25      Pave           6.0    2120.0       1060.0      406.0    1968.0
# 26      Pave           7.0    3166.0       1566.0        0.0    2007.0
# 27      Pave           5.0    1800.0        900.0      222.0    1951.0
# 28      Pave           7.0    3408.0       1704.0        0.0    2007.0
# 29      Pave           6.0    3084.0       1484.0      288.0    1957.0
# 30      Pave           4.0    1040.0        520.0       49.0    1927.0
# ...      ...           ...       ...          ...        ...       ...
# 2890    Pave           4.0    1282.0        641.0      184.0    1925.0
# 2891    Pave           6.0    2605.0        967.0        0.0    1957.0
# 2892    Pave           5.0     729.0          0.0        0.0    1945.0
# 2893    Pave           8.0    2056.0        660.0        0.0    1951.0
# 2894    Grvl           6.0    1152.0        216.0        0.0    1916.0
# 2895    Pave           5.0    3351.0       1573.0      123.0    2005.0
# 2896    Pave           5.0    3240.0       1594.0      128.0    2004.0
# 2897    Pave           6.0    3250.0       1625.0      136.0    1979.0
# 2898    Pave          10.0    3328.0       1664.0        0.0    1978.0
# 2899    Pave           7.0    2982.0       1491.0      120.0    2001.0
# 2900    Pave           6.0    2338.0       1128.0        0.0    1975.0
# 2901    Pave           6.0    3282.0       1632.0        0.0    1958.0
# 2902    Pave           5.0    2784.0       1381.0        0.0    2000.0
# 2903    Pave           8.0    3688.0       1728.0      172.0    2005.0
# 2904    Pave           9.0    3676.0       1838.0      161.0    2005.0
# 2905    Pave           6.0    1600.0          0.0        0.0    1951.0
# 2906    Pave           8.0    2656.0       1288.0        0.0    1997.0
# 2907    Pave           5.0    1568.0        264.0      141.0    1977.0
# 2908    Pave           5.0    1738.0        864.0        0.0    1968.0
# 2909    Pave           8.0    3304.0       1652.0        0.0    1970.0
# 2910    Pave           3.0    1260.0        630.0        0.0    1970.0
# 2911    Pave           5.0    1638.0        546.0        0.0    1972.0
# 2912    Pave           8.0    2464.0       1104.0      160.0    1969.0
# 2913    Pave           5.0    1638.0        546.0        0.0    1970.0
# 2914    Pave           5.0    1638.0        546.0        0.0    1970.0
# 2915    Pave           5.0    1638.0        546.0        0.0    1970.0
# 2916    Pave           6.0    1638.0        546.0        0.0    1970.0
# 2917    Pave           7.0    2448.0       1224.0      474.0    1960.0
# 2918    Pave           6.0    1882.0        912.0       80.0    1992.0
# 2919    Pave           9.0    2996.0        996.0      190.0    1993.0
#
#      YearRemodAdd  YrSold
# Id
# 1          2003.0  2008.0
# 2          1976.0  2007.0
# 3          2002.0  2008.0
# 4          1970.0  2006.0
# 5          2000.0  2008.0
# 6          1995.0  2009.0
# 7          2005.0  2007.0
# 8          1973.0  2009.0
# 9          1950.0  2008.0
# 10         1950.0  2008.0
# 11         1965.0  2008.0
# 12         2006.0  2006.0
# 13         1962.0  2008.0
# 14         2007.0  2007.0
# 15         1960.0  2008.0
# 16         2001.0  2007.0
# 17         1970.0  2010.0
# 18         1967.0  2006.0
# 19         2004.0  2008.0
# 20         1965.0  2009.0
# 21         2006.0  2006.0
# 22         1950.0  2007.0
# 23         2002.0  2008.0
# 24         1976.0  2007.0
# 25         2001.0  2010.0
# 26         2007.0  2009.0
# 27         2000.0  2010.0
# 28         2008.0  2010.0
# 29         1997.0  2006.0
# 30         1950.0  2008.0
# ...           ...     ...
# 2890       1950.0  2006.0
# 2891       1957.0  2006.0
# 2892       1950.0  2006.0
# 2893       1951.0  2006.0
# 2894       1950.0  2006.0
# 2895       2006.0  2006.0
# 2896       2005.0  2006.0
# 2897       1979.0  2006.0
# 2898       1978.0  2006.0
# 2899       2001.0  2006.0
# 2900       1975.0  2006.0
# 2901       1958.0  2006.0
# 2902       2000.0  2006.0
# 2903       2006.0  2006.0
# 2904       2006.0  2006.0
# 2905       1951.0  2006.0
# 2906       1997.0  2006.0
# 2907       1977.0  2006.0
# 2908       2003.0  2006.0
# 2909       1970.0  2006.0
# 2910       1970.0  2006.0
# 2911       1972.0  2006.0
# 2912       1979.0  2006.0
# 2913       1970.0  2006.0
# 2914       1970.0  2006.0
# 2915       1970.0  2006.0
# 2916       1970.0  2006.0
# 2917       1996.0  2006.0
# 2918       1992.0  2006.0
# 2919       1994.0  2006.0
#
# [2917 rows x 80 columns]

# %%
full_df[qual_cols]=full_df[qual_cols].applymap(str)
full_df[quant_cols] = full_df[quant_cols].astype("float64")
quant_cols.remove("SalePrice")

del full_df["TotalBsmtSF"]
del full_df["1stFlrSF"]
del full_df["2ndFlrSF"]

for el in ["TotalBsmtSF","1stFlrSF","2ndFlrSF"]:
    quant_cols.remove(el)


#1458 bc 2 outliers removed in EDA
train_df = full_df[:1458]
test_df  = full_df[1458:].drop("SalePrice", axis = 1)

# %%
train_df["SalePrice"] = train_df["SalePrice"].apply(np.log10)
# Out:
# /home/mtolstokory/anaconda3/envs/42/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
train_df = train_df.reindex(np.random.permutation(train_df.index))
valid_df = train_df[SPLIT:]
train_df = train_df[:SPLIT]

# %%
y_train = train_df["SalePrice"]
del train_df["SalePrice"]

y_valid = valid_df["SalePrice"]
del valid_df["SalePrice"]
y_valid

del full_df["SalePrice"]

# %% [markdown]
# Create columns:

# %%
def make_columns(df):
    keep_num = ["TotalArea", "YearBuilt"]
    keep_cat = ["OverallQual", "HouseStyle", "YrSold", "MoSold", "Neighborhood"]
    
    numeric_features = df[keep_num]
    #.select_dtypes(include = ["float64"])
    
    
    numeric_columns = [tf.feature_column.numeric_column(key = feature) for feature in numeric_features]
    categoric_features = df[keep_cat]
    #.select_dtypes(exclude=["float64"]) 
    
    categoric_dict = {}
    for feature in categoric_features:
        categoric_dict[feature] = df[feature].unique()
    
    categoric_columns = [tf.feature_column.categorical_column_with_vocabulary_list(
        key=feature, vocabulary_list=list(categoric_dict[feature])) for feature in categoric_features]
    return numeric_columns, categoric_columns

# %%
numeric_columns, categoric_columns = make_columns(full_df)

# %%
OUT_DIR = "tf_files_housing"

# %% [markdown]
# Define error function:

# %%
def rmse(labels, predictions):
    
    return {"rmse":tf.metrics.root_mean_squared_error(
    tf.cast(labels, tf.float32), tf.cast(predictions["predictions"], tf.float32))}

# %%
#tf.logging.set_verbosity(tf.logging.ERROR)

# %%
# !rm -rf tf_files_housing/

# %% [markdown]
# Define model function:

# %%
def train_linear_estimator(learning_rate, steps, batch_size):
    
    my_optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
    my_optimizer = tf.contrib.estimator.clip_gradients_by_norm(my_optimizer, 5.0)
    
    linear_estimator = tf.estimator.LinearRegressor(
    feature_columns = numeric_columns+categoric_columns,
    optimizer = my_optimizer,
    config=tf.estimator.RunConfig(keep_checkpoint_max=1).replace(save_summary_steps=2),
    model_dir=OUT_DIR)
    
    linear_estimator = tf.contrib.estimator.add_metrics(linear_estimator, rmse)
    
    periods = 10
    steps_per_period = int(steps/periods)
    
    train_input_fn = tf.estimator.inputs.pandas_input_fn(x=train_df,y=y_train,batch_size=batch_size,shuffle=True)
    predict_train_input_fn = tf.estimator.inputs.pandas_input_fn(x=train_df,y=y_train,batch_size=batch_size,shuffle=False)
    predict_valid_input_fn = tf.estimator.inputs.pandas_input_fn(x=valid_df,y=y_valid,batch_size=batch_size,shuffle=False)
    
    training_errors = []
    validation_errors = []
    training_losses = []
    validation_losses = []
    
    f = plt.Figure()
    graph1 = f.add_subplot(211)
    graph2 = f.add_subplot(212,sharex=graph1)
    
    for period in range(0, periods):
        linear_estimator.train(input_fn=train_input_fn,steps=steps_per_period)
        
        train_error = linear_estimator.evaluate(input_fn=predict_train_input_fn)["rmse"]
        train_loss  =  linear_estimator.evaluate(input_fn=predict_train_input_fn)["loss"]
        valid_error = linear_estimator.evaluate(input_fn=predict_valid_input_fn)["rmse"]
        valid_loss  = linear_estimator.evaluate(input_fn=predict_valid_input_fn)["loss"]
        
        #print("Train error: {}".format(train_error))
        #print("Valid error: {}".format(valid_error))
        training_errors.append(train_error)
        validation_errors.append(valid_error)
        training_losses.append(train_loss)
        validation_losses.append(valid_loss)
        
        
        ax = plt.subplot("211")
        ax.clear()
        ax.set_title("RMSE over time")
        ax.plot(training_errors, label="training error")
        ax.plot(validation_errors, label="validation error")

        ax = plt.subplot("212")
        ax.clear()
        ax.set_title("Loss over time")
        ax.plot(training_losses, label="training loss")
        ax.plot(validation_losses, label="validation loss")
    
    return linear_estimator

# %% [markdown]
# Train model:

# %%
model = train_linear_estimator(learning_rate=0.0001, steps = 400, batch_size=64)
# Out:
# INFO:tensorflow:Using config: {'_model_dir': 'tf_files_housing', '_tf_random_seed': None, '_save_summary_steps': 2, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 1, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f7eb61b9cf8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Using config: {'_model_dir': 'tf_files_housing', '_tf_random_seed': None, '_save_summary_steps': 2, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 1, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f7eb61b9eb8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:From /home/mtolstokory/anaconda3/envs/42/lib/python3.6/site-packages/tensorflow/python/estimator/inputs/queues/feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /home/mtolstokory/anaconda3/envs/42/lib/python3.6/site-packages/tensorflow/python/estimator/inputs/queues/feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From /home/mtolstokory/anaconda3/envs/42/lib/python3.6/site-packages/tensorflow/python/training/monitored_session.py:804: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Saving checkpoints for 0 into tf_files_housing/model.ckpt.
# INFO:tensorflow:loss = 1724.4335, step = 0
# INFO:tensorflow:Saving checkpoints for 16 into tf_files_housing/model.ckpt.
# INFO:tensorflow:Loss for final step: 68.343025.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:46:24
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-16
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:46:25
# INFO:tensorflow:Saving dict for global step 16: average_loss = 1.6780074, global_step = 16, label/mean = 5.2224016, loss = 106.97297, prediction/mean = 6.160558, rmse = 1.2953793
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 16: tf_files_housing/model.ckpt-16
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:46:26
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-16
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:46:26
# INFO:tensorflow:Saving dict for global step 16: average_loss = 1.6780074, global_step = 16, label/mean = 5.2224016, loss = 106.97297, prediction/mean = 6.160558, rmse = 1.2953793
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 16: tf_files_housing/model.ckpt-16
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:46:27
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-16
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:46:28
# INFO:tensorflow:Saving dict for global step 16: average_loss = 1.6676484, global_step = 16, label/mean = 5.220934, loss = 104.347145, prediction/mean = 6.185935, rmse = 1.2913747
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 16: tf_files_housing/model.ckpt-16
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:46:29
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-16
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:46:29
# INFO:tensorflow:Saving dict for global step 16: average_loss = 1.6676484, global_step = 16, label/mean = 5.220934, loss = 104.347145, prediction/mean = 6.185935, rmse = 1.2913747
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 16: tf_files_housing/model.ckpt-16
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-16
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 16 into tf_files_housing/model.ckpt.
# INFO:tensorflow:loss = 101.05969, step = 16
# INFO:tensorflow:Saving checkpoints for 32 into tf_files_housing/model.ckpt.
# INFO:tensorflow:Loss for final step: 20.638515.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:46:34
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-32
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:46:35
# INFO:tensorflow:Saving dict for global step 32: average_loss = 0.25786522, global_step = 32, label/mean = 5.2224016, loss = 16.438908, prediction/mean = 5.105715, rmse = 0.50780433
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 32: tf_files_housing/model.ckpt-32
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:46:35
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-32
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:46:36
# INFO:tensorflow:Saving dict for global step 32: average_loss = 0.25786522, global_step = 32, label/mean = 5.2224016, loss = 16.438908, prediction/mean = 5.105715, rmse = 0.50780433
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 32: tf_files_housing/model.ckpt-32
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:46:37
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-32
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:46:37
# INFO:tensorflow:Saving dict for global step 32: average_loss = 0.23572895, global_step = 32, label/mean = 5.220934, loss = 14.749898, prediction/mean = 5.120701, rmse = 0.48551926
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 32: tf_files_housing/model.ckpt-32
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:46:38
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-32
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:46:39
# INFO:tensorflow:Saving dict for global step 32: average_loss = 0.23572895, global_step = 32, label/mean = 5.220934, loss = 14.749898, prediction/mean = 5.120701, rmse = 0.48551926
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 32: tf_files_housing/model.ckpt-32
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-32
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 32 into tf_files_housing/model.ckpt.
# INFO:tensorflow:loss = 10.670041, step = 32
# INFO:tensorflow:Saving checkpoints for 48 into tf_files_housing/model.ckpt.
# INFO:tensorflow:Loss for final step: 3.7125325.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:46:43
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-48
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:46:44
# INFO:tensorflow:Saving dict for global step 48: average_loss = 0.052998587, global_step = 48, label/mean = 5.2224016, loss = 3.37866, prediction/mean = 5.289322, rmse = 0.23021422
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 48: tf_files_housing/model.ckpt-48
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:46:45
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-48
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:46:45
# INFO:tensorflow:Saving dict for global step 48: average_loss = 0.052998587, global_step = 48, label/mean = 5.2224016, loss = 3.37866, prediction/mean = 5.289322, rmse = 0.23021422
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 48: tf_files_housing/model.ckpt-48
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:46:46
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-48
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:46:47
# INFO:tensorflow:Saving dict for global step 48: average_loss = 0.050708357, global_step = 48, label/mean = 5.220934, loss = 3.1728942, prediction/mean = 5.296603, rmse = 0.22518516
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 48: tf_files_housing/model.ckpt-48
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:46:48
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-48
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:46:48
# INFO:tensorflow:Saving dict for global step 48: average_loss = 0.050708357, global_step = 48, label/mean = 5.220934, loss = 3.1728942, prediction/mean = 5.296603, rmse = 0.22518516
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 48: tf_files_housing/model.ckpt-48
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-48
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 48 into tf_files_housing/model.ckpt.
# INFO:tensorflow:loss = 3.2260995, step = 48
# INFO:tensorflow:Saving checkpoints for 64 into tf_files_housing/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.65874356.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:46:53
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-64
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:46:53
# INFO:tensorflow:Saving dict for global step 64: average_loss = 0.009608781, global_step = 64, label/mean = 5.2224016, loss = 0.6125598, prediction/mean = 5.2440567, rmse = 0.09802439
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 64: tf_files_housing/model.ckpt-64
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:46:54
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-64
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:46:55
# INFO:tensorflow:Saving dict for global step 64: average_loss = 0.009608781, global_step = 64, label/mean = 5.2224016, loss = 0.6125598, prediction/mean = 5.2440567, rmse = 0.09802439
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 64: tf_files_housing/model.ckpt-64
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:46:56
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-64
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:46:56
# INFO:tensorflow:Saving dict for global step 64: average_loss = 0.0099250935, global_step = 64, label/mean = 5.220934, loss = 0.6210273, prediction/mean = 5.244509, rmse = 0.09962476
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 64: tf_files_housing/model.ckpt-64
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:46:57
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-64
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:46:58
# INFO:tensorflow:Saving dict for global step 64: average_loss = 0.0099250935, global_step = 64, label/mean = 5.220934, loss = 0.6210273, prediction/mean = 5.244509, rmse = 0.09962476
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 64: tf_files_housing/model.ckpt-64
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-64
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 64 into tf_files_housing/model.ckpt.
# INFO:tensorflow:loss = 0.56998014, step = 64
# INFO:tensorflow:Saving checkpoints for 80 into tf_files_housing/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.7051976.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:47:02
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-80
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:47:03
# INFO:tensorflow:Saving dict for global step 80: average_loss = 0.0077449605, global_step = 80, label/mean = 5.2224016, loss = 0.49374124, prediction/mean = 5.218254, rmse = 0.08800546
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 80: tf_files_housing/model.ckpt-80
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:47:04
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-80
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:47:04
# INFO:tensorflow:Saving dict for global step 80: average_loss = 0.0077449605, global_step = 80, label/mean = 5.2224016, loss = 0.49374124, prediction/mean = 5.218254, rmse = 0.08800546
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 80: tf_files_housing/model.ckpt-80
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:47:05
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-80
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:47:06
# INFO:tensorflow:Saving dict for global step 80: average_loss = 0.0077735, global_step = 80, label/mean = 5.220934, loss = 0.486399, prediction/mean = 5.2206826, rmse = 0.08816745
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 80: tf_files_housing/model.ckpt-80
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:47:06
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-80
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:47:07
# INFO:tensorflow:Saving dict for global step 80: average_loss = 0.0077735, global_step = 80, label/mean = 5.220934, loss = 0.486399, prediction/mean = 5.2206826, rmse = 0.08816745
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 80: tf_files_housing/model.ckpt-80
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-80
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 80 into tf_files_housing/model.ckpt.
# INFO:tensorflow:loss = 0.43171975, step = 80
# INFO:tensorflow:Saving checkpoints for 96 into tf_files_housing/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.33077034.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:47:12
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-96
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:47:12
# INFO:tensorflow:Saving dict for global step 96: average_loss = 0.02492447, global_step = 96, label/mean = 5.2224016, loss = 1.588935, prediction/mean = 5.3572826, rmse = 0.15787485
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 96: tf_files_housing/model.ckpt-96
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:47:13
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-96
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:47:14
# INFO:tensorflow:Saving dict for global step 96: average_loss = 0.02492447, global_step = 96, label/mean = 5.2224016, loss = 1.588935, prediction/mean = 5.3572826, rmse = 0.15787485
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 96: tf_files_housing/model.ckpt-96
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:47:15
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-96
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:47:15
# INFO:tensorflow:Saving dict for global step 96: average_loss = 0.025958754, global_step = 96, label/mean = 5.220934, loss = 1.6242763, prediction/mean = 5.358771, rmse = 0.16111721
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 96: tf_files_housing/model.ckpt-96
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:47:16
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-96
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:47:16
# INFO:tensorflow:Saving dict for global step 96: average_loss = 0.025958754, global_step = 96, label/mean = 5.220934, loss = 1.6242763, prediction/mean = 5.358771, rmse = 0.16111721
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 96: tf_files_housing/model.ckpt-96
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-96
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 96 into tf_files_housing/model.ckpt.
# INFO:tensorflow:loss = 1.9480802, step = 96
# INFO:tensorflow:Saving checkpoints for 112 into tf_files_housing/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.5976846.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:47:21
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-112
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:47:22
# INFO:tensorflow:Saving dict for global step 112: average_loss = 0.017162722, global_step = 112, label/mean = 5.2224016, loss = 1.0941235, prediction/mean = 5.1219716, rmse = 0.13100657
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 112: tf_files_housing/model.ckpt-112
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:47:23
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-112
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:47:23
# INFO:tensorflow:Saving dict for global step 112: average_loss = 0.017162722, global_step = 112, label/mean = 5.2224016, loss = 1.0941235, prediction/mean = 5.1219716, rmse = 0.13100657
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 112: tf_files_housing/model.ckpt-112
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:47:24
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-112
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:47:25
# INFO:tensorflow:Saving dict for global step 112: average_loss = 0.016977303, global_step = 112, label/mean = 5.220934, loss = 1.0622941, prediction/mean = 5.122687, rmse = 0.13029698
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 112: tf_files_housing/model.ckpt-112
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:47:26
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-112
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:47:26
# INFO:tensorflow:Saving dict for global step 112: average_loss = 0.016977303, global_step = 112, label/mean = 5.220934, loss = 1.0622941, prediction/mean = 5.122687, rmse = 0.13029698
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 112: tf_files_housing/model.ckpt-112
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-112
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 112 into tf_files_housing/model.ckpt.
# INFO:tensorflow:loss = 1.2852447, step = 112
# INFO:tensorflow:Saving checkpoints for 128 into tf_files_housing/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.1299629.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:47:31
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-128
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:47:31
# INFO:tensorflow:Saving dict for global step 128: average_loss = 0.01539365, global_step = 128, label/mean = 5.2224016, loss = 0.9813452, prediction/mean = 5.129446, rmse = 0.12407115
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 128: tf_files_housing/model.ckpt-128
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:47:32
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-128
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:47:33
# INFO:tensorflow:Saving dict for global step 128: average_loss = 0.01539365, global_step = 128, label/mean = 5.2224016, loss = 0.9813452, prediction/mean = 5.129446, rmse = 0.12407115
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 128: tf_files_housing/model.ckpt-128
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:47:34
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-128
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:47:34
# INFO:tensorflow:Saving dict for global step 128: average_loss = 0.01520784, global_step = 128, label/mean = 5.220934, loss = 0.9515763, prediction/mean = 5.1303334, rmse = 0.12332007
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 128: tf_files_housing/model.ckpt-128
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:47:35
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-128
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:47:35
# INFO:tensorflow:Saving dict for global step 128: average_loss = 0.01520784, global_step = 128, label/mean = 5.220934, loss = 0.9515763, prediction/mean = 5.1303334, rmse = 0.12332007
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 128: tf_files_housing/model.ckpt-128
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-128
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 128 into tf_files_housing/model.ckpt.
# INFO:tensorflow:loss = 1.26861, step = 128
# INFO:tensorflow:Saving checkpoints for 144 into tf_files_housing/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.93889546.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:47:40
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-144
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:47:41
# INFO:tensorflow:Saving dict for global step 144: average_loss = 0.014118897, global_step = 144, label/mean = 5.2224016, loss = 0.90007967, prediction/mean = 5.1368337, rmse = 0.11882296
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 144: tf_files_housing/model.ckpt-144
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:47:42
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-144
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:47:42
# INFO:tensorflow:Saving dict for global step 144: average_loss = 0.014118897, global_step = 144, label/mean = 5.2224016, loss = 0.90007967, prediction/mean = 5.1368337, rmse = 0.11882296
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 144: tf_files_housing/model.ckpt-144
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:47:43
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-144
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:47:44
# INFO:tensorflow:Saving dict for global step 144: average_loss = 0.0139901135, global_step = 144, label/mean = 5.220934, loss = 0.8753814, prediction/mean = 5.1376224, rmse = 0.11827981
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 144: tf_files_housing/model.ckpt-144
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:47:45
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-144
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:47:45
# INFO:tensorflow:Saving dict for global step 144: average_loss = 0.0139901135, global_step = 144, label/mean = 5.220934, loss = 0.8753814, prediction/mean = 5.1376224, rmse = 0.11827981
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 144: tf_files_housing/model.ckpt-144
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-144
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 144 into tf_files_housing/model.ckpt.
# INFO:tensorflow:loss = 1.0330256, step = 144
# INFO:tensorflow:Saving checkpoints for 160 into tf_files_housing/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.1541198.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:47:50
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-160
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:47:50
# INFO:tensorflow:Saving dict for global step 160: average_loss = 0.014095796, global_step = 160, label/mean = 5.2224016, loss = 0.898607, prediction/mean = 5.136541, rmse = 0.11872572
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 160: tf_files_housing/model.ckpt-160
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:47:51
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-160
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:47:52
# INFO:tensorflow:Saving dict for global step 160: average_loss = 0.014095796, global_step = 160, label/mean = 5.2224016, loss = 0.898607, prediction/mean = 5.136541, rmse = 0.11872572
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 160: tf_files_housing/model.ckpt-160
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:47:53
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-160
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:47:53
# INFO:tensorflow:Saving dict for global step 160: average_loss = 0.013961482, global_step = 160, label/mean = 5.220934, loss = 0.8735899, prediction/mean = 5.1373386, rmse = 0.11815871
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 160: tf_files_housing/model.ckpt-160
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-26-03:47:54
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-160
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-26-03:47:55
# INFO:tensorflow:Saving dict for global step 160: average_loss = 0.013961482, global_step = 160, label/mean = 5.220934, loss = 0.8735899, prediction/mean = 5.1373386, rmse = 0.11815871
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 160: tf_files_housing/model.ckpt-160

# %% [markdown]
# Generate submission:

# %%
predict_test_input_fn = tf.estimator.inputs.pandas_input_fn(x=test_df,batch_size=64,shuffle=False)
predictions = model.predict(input_fn = predict_test_input_fn)
pred = [prediction['predictions'].item(0) for prediction in predictions]
pred = np.power(10, pred)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from tf_files_housing/model.ckpt-160
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
submission = pd.DataFrame()
submission["Id"] = test_df.index
submission = submission.set_index("Id")
submission["SalePrice"] = pred
submission.to_csv("mtolstok_housing_pred_linear_est.csv")
